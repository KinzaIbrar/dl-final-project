# %%
from ultralytics import YOLO

# %%
model = YOLO("runs/classify/train/weights/best.pt")

# %%
results = model("sun_011.png")
# Out:
# image 1/1 c:\Users\LENOVO\Desktop\final_project2\sun_011.png: 160x160 sun 1.00, moon 0.00, 23.0ms
# Speed: 26.1ms preprocess, 23.0ms inference, 0.1ms postprocess per image at shape (1, 3, 160, 160)

# %%
top_class = results[0].names[results[0].probs.top1]
confidence = results[0].probs.top1conf.item()

# %%
print(f"Class: {top_class} - Confidence: {confidence}")
# Out:
# Class: sun - Confidence: 0.9999719858169556
